# %%
# %load_ext autoreload

# %% [markdown]
# # 引入必要的库

# %%
import os
train='/data/tianmoucData/tianmoucReconDataset_merged/train/'
dirlist = os.listdir(train)
traindata = [train]

val='/data/tianmoucData/tianmoucReconDataset_merged/test/'
vallist = os.listdir(val)
valdata = [val + e for e in vallist]
key_list = []

print('---------------------------------------------------')
for sampleset in traindata:
    print('---->',sampleset,'有：',len(os.listdir(sampleset)),'个样本')
    for e in os.listdir(sampleset):
        print(e)
        key_list.append(e)
print('---------------------------------------------------')
for sampleset in valdata:
    print('---->',sampleset,'有：',len(os.listdir(sampleset)),'个样本')
    for e in os.listdir(sampleset):
        print(e)
        key_list.append(e)
        
all_data = valdata + traindata

key_list = ['test_driving12']
# Out:
# ---------------------------------------------------
# ----> /data/tianmoucData/tianmoucReconDataset_merged/train/ 有： 2 个样本
# normal
# extreme
# ---------------------------------------------------
# ----> /data/tianmoucData/tianmoucReconDataset_merged/test/normal 有： 24 个样本
# test_driving20
# test_man_play_ball3
# outdoor_cross_13
# indoor_phone_1
# test_exam_full3
# test_cross3
# outdoor_cross_2
# test_exam_fan4
# indoor_office_5
# indoor_slefie_3
# outdoor_4huan_2
# test_driving16
# outdoor_cross_10
# outdoor_cross_6
# outdoor_bridge_3
# test_exam_fan_QRcode_3
# test_driving24
# test_driving4
# test_indoor_dog3
# test_driving12
# indoor_keyboard2
# test_running_man_4
# test_driving8
# test_running_man_8
# ----> /data/tianmoucData/tianmoucReconDataset_merged/test/extreme 有： 8 个样本
# test_driving_night_light1
# test_hdr_human2
# test_tunnel8_hdr_ae_double
# underbridge_hdr_3
# test_tunnel2_hdr_blur
# test_driving3
# test_tunnel7_hdr_ae
# test_exam_fan_QRcode_2

# %% [markdown]
# # 普通读取

# %%
# %autoreload
import sys,os
import numpy as np
import torch
import torch.nn.functional as F
import cv2
import math,time
import matplotlib.pyplot as plt

from tianmoucv.isp import fourdirection2xy
from tianmoucv.data import TianmoucDataReader

aim = 1400
for key in key_list:
    dataset = TianmoucDataReader(all_data,MAXLEN=-1,ifSaveFileDict = False,
                              matchkey=key,speedUpRate=1)
    img_list = []
    for index in range(len(dataset)):
        if index<aim:
            continue
        sample = dataset[index]
        if index<= aim+1:
            F0 = sample['F0']
            F1 = sample['F1']
            tsdiff = torch.Tensor(sample['tsdiff'])
            print('shapes:',F0.shape,tsdiff.shape)
            
            plt.figure(figsize=(15,5))
            plt.subplot(1,5,1)
            plt.imshow(F0)
            plt.subplot(1,5,2)
            plt.imshow(tsdiff[:,12,...].permute(1,2,0)*16)
            plt.subplot(1,5,3)
            plt.imshow(F1)
            plt.show()
            
        break
# Out:
# import TianmouCV 0.1, via Y. Lin, T. Wang  pre release version
# ['/data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/rod/rod_compact.tmdat']
# ['/data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/cone/cone_compact.tmdat']
# labelFileName: /data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/label.csv doesnot have status label
# ['/data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/rod/rod_compact.tmdat']
# ['/data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/cone/cone_compact.tmdat']
# labelFileName: /data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/label.csv doesnot have status label
# ['/data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/rod/rod_compact.tmdat']
# ['/data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/cone/cone_compact.tmdat']
# labelFileName: /data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/label.csv doesnot have status label
# test_driving12@/data/tianmoucData/tianmoucReconDataset_merged/test/normal origin length: 82
# test_driving12@/data/tianmoucData/tianmoucReconDataset_merged/test/normal ---legal sample num: 81

# %%
# %autoreload
import sys,os
import numpy as np
import torch
import torch.nn.functional as F
import cv2
import math,time
import matplotlib.pyplot as plt

from tianmoucv.isp import fourdirection2xy,poisson_blend
from tianmoucv.data import TianmoucDataReader

for key in key_list:
    dataset = TianmoucDataReader(all_data,MAXLEN=500,ifSaveFileDict = False,
                              matchkey=key,speedUpRate=1)
    dataLoader = torch.utils.data.DataLoader(dataset, batch_size=1,\
                                          num_workers=4, pin_memory=False, drop_last = False)
    img_list = []
    for index,sample in enumerate(dataLoader,0):
        if index<0:
            continue
        if index == 1:
            F0 = sample['F0_HDR'][0,...]
            F1 = sample['F1_HDR'][0,...]
            tsdiff = sample['tsdiff'][0,...]
            
            plt.figure(figsize=(15,5))
            plt.subplot(1,5,1)
            plt.imshow(F0.numpy())
            plt.subplot(1,5,2)
            plt.imshow(tsdiff[:,12,...].permute(1,2,0).numpy()*4)
            plt.subplot(1,5,3)
            plt.imshow(F1.numpy())
            plt.show()
            break
            
        #print('shapes:',F0.shape,tsdiff.shape)
# Out:
# ['/data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/rod/rod_compact.tmdat']
# ['/data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/cone/cone_compact.tmdat']
# labelFileName: /data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/label.csv doesnot have status label
# ['/data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/rod/rod_compact.tmdat']
# ['/data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/cone/cone_compact.tmdat']
# labelFileName: /data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/label.csv doesnot have status label
# ['/data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/rod/rod_compact.tmdat']
# ['/data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/cone/cone_compact.tmdat']
# labelFileName: /data/tianmoucData/tianmoucReconDataset_merged/test/normal/test_driving12/label.csv doesnot have status label
# test_driving12@/data/tianmoucData/tianmoucReconDataset_merged/test/normal origin length: 82
# test_driving12@/data/tianmoucData/tianmoucReconDataset_merged/test/normal ---legal sample num: 82
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
